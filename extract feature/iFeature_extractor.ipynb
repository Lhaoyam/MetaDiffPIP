# %%
# Current directory
import os
os.chdir('E:\Experiment\work')

# %% [markdown]
# ### 特征提取

# %%
# https://github.com/Superzchen/iFeatureOmega-CLI
import iFeatureOmegaCLI

# %% [markdown]
# ### 读取蛋白质序列，并转化为fasta文件

# %%
import pandas as pd
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO

# 读取csv文件
df = pd.read_csv('E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.csv', header=0, index_col=0)

# 获取蛋白质序列列
sequences = df['0']
# sequences = df[0]

# 创建SeqRecord对象
records = [SeqRecord(Seq(seq), id=str(seq), description='') for i, seq in enumerate(sequences)]

# 写入fasta文件
SeqIO.write(records, 'E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.fasta', 'fasta')
# Out:
# 380

# %% [markdown]
# #### AAC

# %%
# import iFeatureOmegaCLI
import iFeatureOmegaCLI

# read file
protein = iFeatureOmegaCLI.iProtein("E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.fasta")

# display available feature descriptor methods
# protein.display_feature_types()

# calculate feature descriptors.
protein.get_descriptor("AAC")

# display the feature descriptors
print(protein.encodings.shape)

# save feature descriptors
protein.to_csv("E:\Experiment\work\Case Study/19\AAC.csv", "index=False", header=False)
# Out:
# (380, 20)
# True

# %% [markdown]
# #### DPC1

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.fasta")
protein.get_descriptor("DPC type 1") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\Case Study/19\DPC1.csv", "index=False", header=False)
# Out:
# (380, 400)
# True

# %% [markdown]
# ### DPC2

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("DPC type 2") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work/train_feature\原特征\DPC_2.csv", "index=False", header=False)
# Out:
# (2872, 400)
# True

# %% [markdown]
# ### CKSAAP type1

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.fasta")
protein.get_descriptor("CKSAAP type 1") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\Case Study/19\\CKSAAP_1.csv", "index=False", header=False)
# Out:
# (380, 1600)
# True

# %% [markdown]
# ### CKSAAP type2

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("E:\Experiment\work\平衡数据集\去头\protein_sequences_test.fasta")
protein.get_descriptor("CKSAAP type 2") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\平衡数据集\去头\DCKSAAP_2.csv", "index=False", header=False)
# Out:
# (2490, 1600)
# True

# %% [markdown]
# ### CKSAAGP type1

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CKSAAGP type 1") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\DCKSAAGP_1.csv", "index=False", header=False)
# Out:
# (2872, 100)
# True

# %% [markdown]
# ### CKSAAGP type2

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CKSAAGP type 2") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\DCKSAAGP_2.csv", "index=False", header=False)
# Out:
# (2872, 100)
# True

# %% [markdown]
# ### AC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("AC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\AC.csv", "index=False", header=False)
# Out:
# (2872, 24)
# True

# %% [markdown]
# ### BLOSUM62

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("NMBroto") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\NMBroto.csv", "index=False", header=False)
# Out:
# (2872, 24)
# True

# %% [markdown]
# ### Moran

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("Moran") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\Moran.csv", "index=False", header=False)
# Out:
# (2872, 24)
# True

# %% [markdown]
# ### Geary

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("Geary") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\Geary.csv", "index=False", header=False)
# Out:
# (2872, 24)
# True

# %% [markdown]
# ### GAAC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("GAAC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\GAAC.csv", "index=False", header=False)
# Out:
# (2872, 5)
# True

# %% [markdown]
# ### CTriad

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CTriad") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\CTriad.csv", "index=False", header=False)
# Out:
# (2872, 343)
# True

# %% [markdown]
# ### QSOrder

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("QSOrder") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\\QSorder.csv", "index=False", header=False)
# Out:
# (2872, 46)
# True

# %% [markdown]
# ### PCP

# %%
from Pfeature.pfeature import GetPhysicoChemical
features = GetPhysicoChemical("your_sequence")
print(features)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Pfeature.pfeature import GetPhysicoChemical
#       2 features = GetPhysicoChemical("your_sequence")
#       3 print(features)
#
# ModuleNotFoundError: No module named 'Pfeature'

# %% [markdown]
# ### DDE

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("E:\Experiment\work\Case Study/19\scan_mutants_19 - 副本.fasta")
protein.get_descriptor("DDE") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\Case Study/19\DDE.csv", "index=False", header=False)
# Out:
# (380, 400)
# True

# %% [markdown]
# #### CTDC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CTDC")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\CTDC.csv", "index=False", header=False)
# Out:
# (2872, 39)
# True

# %% [markdown]
# #### CTDT

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CTDT")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\CTDT.csv", "index=False", header=False)
# Out:
# (2872, 39)
# True

# %% [markdown]
# #### CTDD

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CTDD")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\CTDD.csv", "index=False", header=False)
# Out:
# (2872, 195)
# True

# %% [markdown]
# ### TPC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("TPC type 1")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\TPC_1.csv", "index=False", header=False)

# %% [markdown]
# ### TPC2

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("TPC type 2")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work/train_feature\原特征\TPC_2.csv", "index=False", header=False)
# Out:
# (2872, 8000)
# True

# %% [markdown]
# ### ASDC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("ASDC")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\ASDC.csv", "index=False", header=False)
# Out:
# (2872, 400)
# True

# %% [markdown]
# ### PseKRAAC type1

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("PseKRAAC type 1")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\PseKRAAC_1.csv", "index=False", header=False)
# Out:
# (2872, 4)
# True

# %% [markdown]
# ### DistancePair

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("DistancePair")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\DistancePair.csv", "index=False", header=False)
# Out:
# (2872, 20)
# True

# %% [markdown]
# ### GTPC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("GTPC type 1")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\GTPC_1.csv", "index=False", header=False)
# Out:
# (2872, 125)
# True

# %% [markdown]
# ### GDPC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("GDPC type 1")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\GDPC_1.csv", "index=False", header=False)
# Out:
# (2872, 25)
# True

# %% [markdown]
# ### GDPC2

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("GDPC type 2")
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\GDPC_2.csv", "index=False", header=False)
# Out:
# (2872, 25)
# True

# %% [markdown]
# ### PAAC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("PAAC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\PAAC.csv", "index=False", header=False)
# Out:
# (2872, 23)
# True

# %% [markdown]
# ### APAAC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("APAAC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\APAAC.csv", "index=False", header=False)
# Out:
# (2872, 26)
# True

# %% [markdown]
# ### 对序列进行填充

# %%
# 获得fasta文件中蛋白质序列的最大长度
from Bio import SeqIO

def find_max_length(fasta_file):
    max_length = 0
    for record in SeqIO.parse(fasta_file, "fasta"):
        if len(record.seq) > max_length:
            max_length = len(record.seq)
    return max_length

fasta_file = "protein_sequences_train.fasta"  # fasta文件路径
max_length = find_max_length(fasta_file)
print("最长的序列长度是：", max_length)
# Out:
# 最长的序列长度是： 25

# %%
def pad_or_truncate(sequence, target_length):
    # 如果序列长度小于目标长度，则进行填充
    if len(sequence) < target_length:
        return sequence.ljust(target_length, 'X')
    # 如果序列长度大于目标长度，则进行截断
    else:
        return sequence[:target_length]

# %%
from Bio import Seq
from Bio import SeqIO

def pad_sequences_in_fasta(input_file, output_file, target_length):
    with open(output_file, 'w') as out_f:
        for record in SeqIO.parse(input_file, 'fasta'):
            padded_sequence = pad_or_truncate(str(record.seq), target_length)
            record.seq = Seq.Seq(padded_sequence)
            SeqIO.write(record, out_f, 'fasta')

input_file = 'protein_sequences_train.fasta'
output_file = 'sequences.fasta'
target_length = max_length  # or whatever length you want
pad_sequences_in_fasta(input_file, output_file, target_length)

# %% [markdown]
#  ### Binary

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("binary")
print(protein.encodings)
protein.to_csv("E:\Experiment\work\\train_feature\Binary.csv", "index=False", header=False)

# %% [markdown]
# #### AAIdex

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("AAIndex")
print(protein.encodings)
protein.to_csv("E:\Experiment\work\\train_feature\AAI.csv", "index=False", header=False)

# %% [markdown]
# ### OPF

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("OPF_10bit")
print(protein.encodings)
protein.to_csv("E:\Experiment\work\\train_feature\OPF.csv", "index=False", header=False)

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("protein_sequences_train.fasta")
protein.get_descriptor("CKSAAP type 1") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\DCKSAAP_1.csv", "index=False", header=False)

# %% [markdown]
# ### KSCTriad

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("KSCTriad") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\KSCTriad.csv", "index=False", header=False)
# Out:
# (2872, 1372)
# True

# %% [markdown]
# ### SOCNumber

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("SOCNumber") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\SOCNumber.csv", "index=False", header=False)
# Out:
# (2872, 6)
# True

# %% [markdown]
# ### DistancePair

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("SOCNumber") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\DistancePair.csv", "index=False", header=False)
# Out:
# (2872, 6)
# True

# %% [markdown]
# ### CC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("CC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\CC.csv", "index=False", header=False)
# Out:
# (2872, 168)
# True

# %% [markdown]
# ### ACC

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("ACC") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\ACC.csv", "index=False", header=False)
# Out:
# (2872, 192)
# True

# %% [markdown]
# ### PseKRAAC_1

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("PseKRAAC type 16") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\PseKRAAC_16.csv", "index=False", header=False)
# Out:
# (2872, 4)
# True

# %% [markdown]
# ### KNN

# %%
import iFeatureOmegaCLI
protein = iFeatureOmegaCLI.iProtein("sequences.fasta")
protein.get_descriptor("KNN") # normoalized=True
print(protein.encodings.shape)
protein.to_csv("E:\Experiment\work\\train_feature\KNN.csv", "index=False", header=False)
# Out:
# (2872, 30)
# True
